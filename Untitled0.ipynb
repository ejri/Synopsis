# %% [markdown]
# <a href="https://colab.research.google.com/github/ejri/Synopsis/blob/cohort2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
d= pd.read_csv("maneuver_report (1).tsv", sep=("\t"), index_col=0)

d.head()
d.describe()

# %matplotlib inline
#
#d['insulation'].plot()
#d.plot(kind='bar')

#d.sort_values(['insulation', 'vertical_distance']).plot()

# view sum of NaN in each Series
d.isna().sum()

# report on the series
d.info()
d.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
# source_intensity       100000 non-null float64
# horizontal_distance    100000 non-null float64
# vertical_distance      100000 non-null float64
# hearing_damage         100000 non-null int64
# felt_damage            100000 non-null int64
# insulation             100000 non-null float64
# dtypes: float64(4), int64(2)
# memory usage: 5.3 MB
#    source_intensity  horizontal_distance  ...  felt_damage  insulation
# 0      1.946567e+05           706.118918  ...            1    0.603576
# 1      8.823720e-01           268.929047  ...            1    0.235338
# 2      9.869254e+05           615.087438  ...            0    0.050829
# 3      1.597790e+12           376.152308  ...            0    0.308507
# 4      2.078979e-01           434.519439  ...            1    0.909739
# 5      1.627332e-01           509.520853  ...            0    0.804539
# ...

# %%
d['processed_intensity']=np.log10(d['source_intensity'])
d.drop(columns=['source_intensity'],inplace=True)

# %%
d.head()
# Out:
#    horizontal_distance  vertical_distance  ...  insulation  processed_intensity
# 0           706.118918         812.368143  ...    0.603576             5.289269
# 1           268.929047         481.154338  ...    0.235338            -0.054348
# 2           615.087438         234.092880  ...    0.050829             5.994284
# 3           376.152308         222.272373  ...    0.308507            12.203520
# 4           434.519439         431.469844  ...    0.909739            -0.682150
#
# [5 rows x 6 columns]

# %%
x=np.array(d.processed_intensity)

# def normalizing(data):
#     for i in range(len(data)):
#         x[i]=(x[i]-min(x))/(min(x)-max(x))

# normalizing(x)
# print(x)

sns.pairplot(d)

# %%
sns.pairplot(d, hue='hearing_damage')

# %%
d['hearing_damage'].corr(d['felt_damage'])
# Out:
# 0.0011981887574237223

# %%
# since there was no corrolecation between the two, dropping the column makes more sense

d.drop(columns=['felt_damage'], inplace=True)

# %%
# find the pythagorous relation between horizontal and vertical
d['distance']=np.hypot(d['horizontal_distance'],d['vertical_distance'])
d.drop(columns=['horizontal_distance','vertical_distance'], inplace=True)

# %%
sns.pairplot(d, hue= 'hearing_damage')

# %%
# homework reduce the data further.
